# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
user = 'postgres'
password = 'mjesbb51187'
database = 'PMS_ASH'
host = 'localhost'
port = '5432'

# %%
engine = create_engine (f"postgresql://{user}:{password}@{host}:{port}/{database}")

# %%
df = pd.read_csv (r"C:\Users\Khaled Ahmed\Desktop\fwd_analysis_ASH\fwd_data_part_a.csv")

# %%
df.to_sql ('fwd_data', con = engine)
# Out:
# 489

# %%
import pandas as pd
import os
import datetime

# %%
main_folder = r"C:\Users\Khaled Ahmed\Desktop\fwd_analysis_ASH\001_batch_one"

# %%
list_folders = os.listdir(main_folder)

# %%
list_folders
# Out:
# ['H10-M-L2-0-16.GPX',
#  'H10-M-L2-0-16.mdb',
#  'H10-M-L2-1111-1131.GPX',
#  'H10-M-L2-1111-1131.mdb',
#  'H10-M-L2-112-143.GPX',
#  'H10-M-L2-112-143.mdb',
#  'H10-M-L2-1131-1161.GPX',
#  'H10-M-L2-1131-1161.mdb',
#  'H10-M-L2-1161-1191.GPX',
#  'H10-M-L2-1161-1191.mdb',
#  'H10-M-L2-1191-1221.GPX',
#  'H10-M-L2-1191-1221.mdb',
#  'H10-M-L2-1221-1253.GPX',
#  'H10-M-L2-1221-1253.mdb',
#  'H10-M-L2-1253-1283.GPX',
#  'H10-M-L2-1253-1283.mdb',
#  'H10-M-L2-1283-1314.GPX',
#  'H10-M-L2-1283-1314.mdb',
#  'H10-M-L2-1315-1345.GPX',
#  'H10-M-L2-1315-1345.mdb',
#  'H10-M-L2-1345-1375.GPX',
#  'H10-M-L2-1345-1375.mdb',
#  'H10-M-L2-1375-1405.GPX',
#  'H10-M-L2-1375-1405.mdb',
#  'H10-M-L2-1407-1447.GPX',
#  'H10-M-L2-1407-1447.mdb',
#  'H10-M-L2-143-173.GPX',
#  'H10-M-L2-143-173.mdb',
#  'H10-M-L2-1447-1479.GPX',
#  'H10-M-L2-1447-1479.mdb',
#  'H10-M-L2-173-203.GPX',
#  'H10-M-L2-173-203.mdb',
#  'H10-M-L2-203-233.GPX',
#  'H10-M-L2-203-233.mdb',
#  'H10-M-L2-233-263.GPX',
# ...

# %%
modified_date_list = []
for file in list_folders:
    file_path = os.path.join (main_folder, file)
    modified_date_float = os.path.getmtime(file_path)
    modified_date_time = datetime.datetime.fromtimestamp(modified_date_float)
    modified_date_list.append (modifi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 file_path = os.path.join (main_folder, file)
#       4 modified_date = os.path.getmtime(file_path)
# ----> 5 modified_date_list += modified_date
#
# TypeError: 'float' object is not iterable

# %%
modified_date
# Out:
# 1673240542.0

# %%
trial_path = r"C:\Users\Khaled Ahmed\Desktop\fwd_analysis_ASH\001_batch_one\H5-M-L2-38-73.mdb"

# %%
modified_date = os.path.getmtime (trial_path)

# %%
modified_date
# Out:
# 1679219510.0
